# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '104_Getting_started_with_pandas.py',
#  '106_Getting_started _with_jupyter.py',
#  '107-112_Loading files.ipynb',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.xlsx',
#  'Untitled.ipynb',
#  'Untitled1.ipynb']

# %%
#When header is absent:

import pandas
df1 = pandas.read_csv("supermarkets.csv", header = None)
df1
# Out:
#     0                1              2                 3        4            5  \
# 0  ID          Address           City             State  Country         Name
# 1   1     3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2   2   735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3   3      332 Hill St  San Francisco  California 94114      USA  Super River
# 4   4     3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   5  1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#            6
# 0  Employees
# 1          8
# 2         15
# 3         25
# 4         10
# 5         12
# 6         20

# %%
#Assigning column names:

df1.columns = ("ID","Address","City","ZIP","Country","Name","Employees")
df1
# Out:
#    ID          Address           City               ZIP  Country         Name  \
# 0  ID          Address           City             State  Country         Name
# 1   1     3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2   2   735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3   3      332 Hill St  San Francisco  California 94114      USA  Super River
# 4   4     3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   5  1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#    Employees
# 0  Employees
# 1          8
# 2         15
# 3         25
# 4         10
# 5         12
# 6         20

# %%
#Assigning an index

df2 = df1.set_index("ID")
df2
# Out:
#             Address           City               ZIP  Country         Name  \
# ID
# ID          Address           City             State  Country         Name
# 1      3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114      USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#     Employees
# ID
# ID  Employees
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df3 = df1.set_index("Address")
df3
# Out:
#                  ID           City               ZIP  Country         Name  \
# Address
# Address          ID           City             State  Country         Name
# 3666 21st St      1  San Francisco          CA 94114      USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119      USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114      USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114      USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California      USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114      USA   Richvalley
#
#                  Employees
# Address
# Address          Employees
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
#Extracting data from DataFrames.

#1. Labeled based Indexing

df4 = df3.loc["735 Dolores St":"3995 23rd St", "Country": "Employees"]
df4
# Out:
#                Country         Name Employees
# Address
# 735 Dolores St     USA  Bready Shop        15
# 332 Hill St        USA  Super River        25
# 3995 23rd St       USA   Ben's Shop        10

# %%
#2. Index based Indexing

df5 = df3.iloc[1:3,1:3]
df5
# Out:
#                          City       ZIP
# Address
# 3666 21st St    San Francisco  CA 94114
# 735 Dolores St  San Francisco  CA 94119

# %%
df6 =df3.iloc[3,1:4]
df6
# Out:
# City          San Francisco
# ZIP        California 94114
# Country                 USA
# Name: 332 Hill St, dtype: object

# %%
# Deleting rows and columns from DataFrame
# - you pass 1 to delete rows and 0 to delete columns 

df7 = df3.drop("City",1)
df7
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7648\3834367237.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df7 = df3.drop("City",1)
#                  ID               ZIP  Country         Name  Employees
# Address
# Address          ID             State  Country         Name  Employees
# 3666 21st St      1          CA 94114      USA      Madeira          8
# 735 Dolores St    2          CA 94119      USA  Bready Shop         15
# 332 Hill St       3  California 94114      USA  Super River         25
# 3995 23rd St      4          CA 94114      USA   Ben's Shop         10
# 1056 Sanchez St   5        California      USA      Sanchez         12
# 551 Alvarado St   6          CA 94114      USA   Richvalley         20

# %%
df7.drop("332 Hill St",0)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7648\2526208556.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df7.drop("332 Hill St",0)
#                  ID         ZIP  Country         Name  Employees
# Address
# Address          ID       State  Country         Name  Employees
# 3666 21st St      1    CA 94114      USA      Madeira          8
# 735 Dolores St    2    CA 94119      USA  Bready Shop         15
# 3995 23rd St      4    CA 94114      USA   Ben's Shop         10
# 1056 Sanchez St   5  California      USA      Sanchez         12
# 551 Alvarado St   6    CA 94114      USA   Richvalley         20

# %%
#dropping rows and columns by indexing
df7.drop(df7.columns[0:3],1)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7648\1759015992.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df7.drop(df7.columns[0:3],1)
# C:\Users\User\AppData\Local\Temp\ipykernel_7648\1759015992.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df7.drop(df7.index[0:3],0)
#                 ID               ZIP Country         Name Employees
# Address
# 332 Hill St      3  California 94114     USA  Super River        25
# 3995 23rd St     4          CA 94114     USA   Ben's Shop        10
# 1056 Sanchez St  5        California     USA      Sanchez        12
# 551 Alvarado St  6          CA 94114     USA   Richvalley        20

# %%
df7.drop(df7.index[0:3],0)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7648\78181591.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df7.drop(df7.index[0:3],0)
#                 ID               ZIP Country         Name Employees
# Address
# 332 Hill St      3  California 94114     USA  Super River        25
# 3995 23rd St     4          CA 94114     USA   Ben's Shop        10
# 1056 Sanchez St  5        California     USA      Sanchez        12
# 551 Alvarado St  6          CA 94114     USA   Richvalley        20

# %%
#Updating and adding columns
#Adding :

# %%
df3
# Out:
#                  ID           City               ZIP  Country         Name  \
# Address
# Address          ID           City             State  Country         Name
# 3666 21st St      1  San Francisco          CA 94114      USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119      USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114      USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114      USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California      USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114      USA   Richvalley
#
#                  Employees
# Address
# Address          Employees
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df3["Continent"]= df7.shape[0]*["North America"]
df3
# Out:
#                  ID           City               ZIP  Country         Name  \
# Address
# Address          ID           City             State  Country         Name
# 3666 21st St      1  San Francisco          CA 94114      USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119      USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114      USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114      USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California      USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114      USA   Richvalley
#
#                  Employees      Continent
# Address
# Address          Employees  North America
# 3666 21st St             8  North America
# 735 Dolores St          15  North America
# 332 Hill St             25  North America
# 3995 23rd St            10  North America
# 1056 Sanchez St         12  North America
# 551 Alvarado St         20  North America

# %%
#Modifying columns:

df3["Continent"]= df3["Country"]+","+"North America"
df3
# Out:
#                  ID           City               ZIP  Country         Name  \
# Address
# Address          ID           City             State  Country         Name
# 3666 21st St      1  San Francisco          CA 94114      USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119      USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114      USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114      USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California      USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114      USA   Richvalley
#
#                  Employees              Continent
# Address
# Address          Employees  Country,North America
# 3666 21st St             8      USA,North America
# 735 Dolores St          15      USA,North America
# 332 Hill St             25      USA,North America
# 3995 23rd St            10      USA,North America
# ...

# %%
df8 = df3.drop(df3.index[0:1])
df8
# Out:
#                 ID           City               ZIP Country         Name  \
# Address
# 3666 21st St     1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      3  San Francisco  California 94114     USA  Super River
# 3995 23rd St     4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St  5  San Francisco        California     USA      Sanchez
# 551 Alvarado St  6  San Francisco          CA 94114     USA   Richvalley
#
#                 Employees          Continent
# Address
# 3666 21st St            8  USA,North America
# 735 Dolores St         15  USA,North America
# 332 Hill St            25  USA,North America
# 3995 23rd St           10  USA,North America
# 1056 Sanchez St        12  USA,North America
# 551 Alvarado St        20  USA,North America

# %%
#Adding Rows
df8_t = df8.T
df8_t
#Rows becomes columns and columns become rows.
#T means TRANSPOSE#
# Out:
# Address         3666 21st St     735 Dolores St        332 Hill St  \
# ID                         1                  2                  3
# City           San Francisco      San Francisco      San Francisco
# ZIP                 CA 94114           CA 94119   California 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop        Super River
# Employees                  8                 15                 25
# Continent  USA,North America  USA,North America  USA,North America
#
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St
# ID                         4                  5                  6
# City           San Francisco      San Francisco      San Francisco
# ZIP                 CA 94114         California           CA 94114
# Country                  USA                USA                USA
# Name              Ben's Shop            Sanchez         Richvalley
# ...

# %%
df8_t["My Address"] = [7,"Trivandrum","695017","India","Dwaraka","100","India,Asia"]
df8_t
# Out:
# Address         3666 21st St     735 Dolores St        332 Hill St  \
# ID                         1                  2                  3
# City           San Francisco      San Francisco      San Francisco
# ZIP                 CA 94114           CA 94119   California 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop        Super River
# Employees                  8                 15                 25
# Continent  USA,North America  USA,North America  USA,North America
#
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St  My Address
# ID                         4                  5                  6           7
# City           San Francisco      San Francisco      San Francisco  Trivandrum
# ZIP                 CA 94114         California           CA 94114      695017
# Country                  USA                USA                USA       India
# ...

# %%
#Making the rows back to columns

df8 = df8_t.T
df8
# Out:
#                 ID           City               ZIP Country         Name  \
# Address
# 3666 21st St     1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      3  San Francisco  California 94114     USA  Super River
# 3995 23rd St     4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St  5  San Francisco        California     USA      Sanchez
# 551 Alvarado St  6  San Francisco          CA 94114     USA   Richvalley
# My Address       7     Trivandrum            695017   India      Dwaraka
#
#                 Employees          Continent
# Address
# 3666 21st St            8  USA,North America
# 735 Dolores St         15  USA,North America
# 332 Hill St            25  USA,North America
# 3995 23rd St           10  USA,North America
# 1056 Sanchez St        12  USA,North America
# 551 Alvarado St        20  USA,North America
# ...

# %%
#Modifying the rows:
df8_t["3666 21st St"] = [7,"Trivandrum","695017","India","Dwaraka","100","India,Asia"]
df8 = df8_t.T
df8
# Out:
#                 ID           City               ZIP Country         Name  \
# Address
# 3666 21st St     7     Trivandrum            695017   India      Dwaraka
# 735 Dolores St   2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      3  San Francisco  California 94114     USA  Super River
# 3995 23rd St     4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St  5  San Francisco        California     USA      Sanchez
# 551 Alvarado St  6  San Francisco          CA 94114     USA   Richvalley
# My Address       7     Trivandrum            695017   India      Dwaraka
#
#                 Employees          Continent
# Address
# 3666 21st St          100         India,Asia
# 735 Dolores St         15  USA,North America
# 332 Hill St            25  USA,North America
# 3995 23rd St           10  USA,North America
# 1056 Sanchez St        12  USA,North America
# 551 Alvarado St        20  USA,North America
# ...
