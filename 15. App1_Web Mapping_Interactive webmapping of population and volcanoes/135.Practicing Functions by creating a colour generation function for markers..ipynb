# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '128. Creating an HTML map with python.ipynb',
#  '130-131.  Adding pointers to map..ipynb',
#  '133. Practicing file processing by adding markers from files.ipynb',
#  '133.Practicing String manipulation by adding text on the Map popup Window..ipynb',
#  '134. Adding HTML on popups.ipynb',
#  'Map.html',
#  'Map1.html',
#  'Map2.html',
#  'Map_html_popup_advanced.html',
#  'Map_html_popup_simple.html',
#  'Untitled.ipynb',
#  'Volcanoes.txt',
#  'Webmap_datasources',
#  'Webmap_datasources.zip',
#  'world.json']

# %%
import folium
import pandas

data = pandas.read_csv("Volcanoes.txt")
data
# Out:
#     VOLCANX020    NUMBER            NAME       LOCATION  \
# 0        509.0  1201-01=           Baker  US-Washington
# 1        511.0  1201-02-    Glacier Peak  US-Washington
# 2        513.0  1201-03-         Rainier  US-Washington
# 3        515.0  1201-05-      St. Helens  US-Washington
# 4        516.0  1201-04-           Adams  US-Washington
# ..         ...       ...             ...            ...
# 57       580.0  1210-03-  Valles Caldera  US-New Mexico
# 58       581.0  1209-02-   Sunset Crater     US-Arizona
# 59       584.0  1203-20-           Amboy  US-California
# 60       586.0  1210-02-    Zuni-Bandera  US-New Mexico
# 61       588.0  1210-01-       Carrizozo  US-New Mexico
#
#                    STATUS    ELEV             TYPE TIMEFRAME        LAT  \
# 0              Historical  3285.0  Stratovolcanoes        D3  48.776798
# 1        Tephrochronology  3213.0    Stratovolcano        D4  48.111801
# 2        Dendrochronology  4392.0    Stratovolcano        D3  46.869801
# ...

# %%
lat = list(data ['LAT'])
lon = list(data ['LON'])
elev = list(data['ELEV'])

# %%
#Defining a function for presenting various colours for different elevation values


def color_producer(elevation):
    if elevation<1000:
        return 'green'
    elif 1000 <= elevation <3000:
        return 'orange'
    else:
        return 'red'

# %%
#Adding markers from file volcanoes.txt along with their elevation

map = folium.Map(location = [39.86546881629921, -105.00650100494674],zoom_start = 5,tiles = "Stamen Terrain")
fg = folium.FeatureGroup(name = "Watashi no map")     

for lt,ln,el in zip(lat,lon,elev):
    fg.add_child(folium.Marker(location = [lt,ln],popup = str(el) + "m", icon = folium.Icon(color = color_producer(el))))

map.add_child(fg)
map.save('Map3.html')

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
