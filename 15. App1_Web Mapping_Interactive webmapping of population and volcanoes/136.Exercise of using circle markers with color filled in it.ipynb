# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '128. Creating an HTML map with python.ipynb',
#  '130-131.  Adding pointers to map..ipynb',
#  '133. Practicing file processing by adding markers from files.ipynb',
#  '133.Practicing String manipulation by adding text on the Map popup Window..ipynb',
#  '134. Adding HTML on popups.ipynb',
#  '135.Practicing Functions by creating a colour generation function for markers..ipynb',
#  'Map.html',
#  'Map1.html',
#  'Map2.html',
#  'Map3.html',
#  'Map_html_popup_advanced.html',
#  'Map_html_popup_simple.html',
#  'Untitled.ipynb',
#  'Volcanoes.txt',
#  'Webmap_datasources',
#  'Webmap_datasources.zip',
#  'world.json']

# %%
import folium
import pandas

# %%
data = pandas.read_csv("Volcanoes.txt")
data
# Out:
#     VOLCANX020    NUMBER            NAME       LOCATION  \
# 0        509.0  1201-01=           Baker  US-Washington
# 1        511.0  1201-02-    Glacier Peak  US-Washington
# 2        513.0  1201-03-         Rainier  US-Washington
# 3        515.0  1201-05-      St. Helens  US-Washington
# 4        516.0  1201-04-           Adams  US-Washington
# ..         ...       ...             ...            ...
# 57       580.0  1210-03-  Valles Caldera  US-New Mexico
# 58       581.0  1209-02-   Sunset Crater     US-Arizona
# 59       584.0  1203-20-           Amboy  US-California
# 60       586.0  1210-02-    Zuni-Bandera  US-New Mexico
# 61       588.0  1210-01-       Carrizozo  US-New Mexico
#
#                    STATUS    ELEV             TYPE TIMEFRAME        LAT  \
# 0              Historical  3285.0  Stratovolcanoes        D3  48.776798
# 1        Tephrochronology  3213.0    Stratovolcano        D4  48.111801
# 2        Dendrochronology  4392.0    Stratovolcano        D3  46.869801
# 3              Historical  2549.0    Stratovolcano        D1  46.199799
# 4        Tephrochronology  3742.0    Stratovolcano        D6  46.205799
# ..                    ...     ...              ...       ...        ...
# 57  Pleistocene-Fumarolic  3430.0          Caldera         Q  35.869999
# 58       Dendrochronology  2447.0      Cinder cone        D6  35.369999
# 59               Holocene   288.0      Cinder cone         U  34.549999
# 60           Anthropology  2550.0   Volcanic field        D7  34.799999
# 61               Holocene  1731.0      Cinder cone         U  33.780102
#
#            LON
# 0  -121.810997
# 1  -121.111000
# 2  -121.751000
# 3  -122.181000
# 4  -121.490997
# ..         ...
# 57 -106.570999
# 58 -111.501000
# 59 -115.780998
# 60 -108.001000
# 61 -105.931000
#
# [62 rows x 10 columns]

# %%
lat = list(data['LAT'])
lon = list(data['LON'])
elev = list(data['ELEV'])

# %%
def color_producer(elevation):
    if elevation <1000:
        return 'green'
    elif elevation >= 1000 and elevation < 3000:
        return 'orange'
    else:
        return 'red'

# %%
map = folium.Map(location = [39.86546881629921, -105.00650100494674],zoom_start = 5,tiles = "Stamen Terrain")
fg = folium.FeatureGroup(name = "Watashi no map")

for lt,ln,el in zip (lat,lon,elev):
    fg.add_child(folium.CircleMarker(location = [lt,ln] ,radius = 6, popup = str(el)+"m" , fill_color = color_producer(el),color = 'grey',fill_opacity = 0.7))
    
map.add_child(fg)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ebf864b07ce508820066597bbb49bf5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ebf864b07ce508820066597bbb49bf5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1ebf864b07ce508820066597bbb49bf5 = L.map(
#                 &quot;map_1ebf864b07ce508820066597bbb49bf5&quot;,
#                 {
#                     center: [39.86546881629921, -105.00650100494674],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_45962f5ed8e0ccfc89d443d4eada5874 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1ebf864b07ce508820066597bbb49bf5);
#
#
#             var feature_group_309a619ff1b8ac98154f650f1eec439d = L.featureGroup(
#                 {}
#             ).addTo(map_1ebf864b07ce508820066597bbb49bf5);
#
#
#             var circle_marker_97571c1ba52f916f1affb8b2caa3e8f5 = L.circleMarker(
#                 [48.7767982, -121.810997],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;grey&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_309a619ff1b8ac98154f650f1eec439d);
#
#
#         var popup_a1fafa2e0b05797bc893d555f73c865f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_cea26b9b4aff632e6588a2e5dc3bf0a2 = $(`&lt;div id=&quot;html_cea26b9b4aff632e6588a2e5dc3bf0a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3285.0m&lt;/div&gt;`)[0];
#             popup_a1fafa2e0b05797bc893d555f73c865f.setContent(html_cea26b9b4aff632e6588a2e5dc3bf0a2);
#
#
#         circle_marker_97571c1ba52f916f1affb8b2caa3e8f5.bindPopup(popup_a1fafa2e0b05797bc893d555f73c865f)
#         ;
#
#
#
#
#             var circle_marker_867bb80150715b7fcbb0f6d97db99f07 = L.circleMarker(
#                 [48.1118011, -121.1110001],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;grey&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_309a619ff1b8ac98154f650f1eec439d);
#
#
#         var popup_dab533194ec9a26be6fc036ce61413bb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_518c7dbe993bc69fc8bfff3a28a704e9 = $(`&lt;div id=&quot;html_518c7dbe993bc69fc8bfff3a28a704e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3213.0m&lt;/div&gt;`)[0];
#             popup_dab533194ec9a26be6fc036ce61413bb.setContent(html_518c7dbe993bc69fc8bfff3a28a704e9);
#
#
#         circle_marker_867bb80150715b7fcbb0f6d97db99f07.bindPopup(popup_dab533194ec9a26be6fc036ce61413bb)
#         ;
#
#
#
#
#             var circle_marker_f7e0d339b5c3264717ad296917a33433 = L.circleMarker(
#                 [46.8698006, -121.7509995],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;grey&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_309a619ff1b8ac98154f650f1eec439d);
#
#
#         var popup_092c579672f3d4cbd021d2868f236bad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_fbfc7db054d2be4d0727590a1f23334b = $(`&lt;div id=&quot;html_fbfc7db054d2be4d0727590a1f23334b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4392.0m&lt;/div&gt;`)[0];
#             popup_092c579672f3d4cbd021d2868f236bad.setContent(html_fbfc7db054d2be4d0727590a1f23334b);
#
#
#         circle_marker_f7e0d339b5c3264717ad296917a33433.bindPopup(popup_092c579672f3d4cbd021d2868f236bad)
#         ;
#
#
#
#
#             var circle_marker_6795ff9fefae9f69ed39abe146b3963e = L.circleMarker(
#                 [46.199

# %%
help(folium.CircleMarker)
# Out:
# Help on class CircleMarker in module folium.vector_layers:
#
# class CircleMarker(folium.map.Marker)
#  |  CircleMarker(location=None, radius=10, popup=None, tooltip=None, **kwargs)
#  |
#  |  A circle of a fixed size with radius specified in pixels.
#  |
#  |  See :func:`folium.vector_layers.path_options` for the `Path` options.
#  |
#  |  Parameters
#  |  ----------
#  |  location: tuple[float, float]
#  |      Latitude and Longitude pair (Northing, Easting)
#  |  popup: string or folium.Popup, default None
#  |      Input text or visualization for object displayed when clicking.
#  |  tooltip: str or folium.Tooltip, default None
#  |      Display a text when hovering over the object.
#  |  radius: float, default 10
#  |      Radius of the circle marker, in pixels.
#  |  **kwargs
#  |      Other valid (possibly inherited) options. See:
#  |      https://leafletjs.com/reference-1.6.0.html#circlemarker
#  |
#  |  Method resolution order:
#  |      CircleMarker
#  |      folium.map.Marker
#  |      branca.element.MacroElement
#  |      branca.element.Element
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, location=None, radius=10, popup=None, tooltip=None, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from folium.map.Marker:
#  |
#  |  render(self)
#  |      Renders the HTML representation of the element.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from branca.element.Element:
#  |
#  |  add_child(self, child, name=None, index=None)
#  |      Add a child.
#  |
#  |  add_children(self, child, name=None, index=None)
#  |      Add a child.
#  |
#  |  add_to(self, parent, name=None, index=None)
#  |      Add element to a parent.
#  |
#  |  get_bounds(self)
#  |      Computes the bounds of the object and all it's children
#  |      in the form [[lat_min, lon_min], [lat_max, lon_max]].
#  |
#  |  get_name(self)
#  |      Returns a string representation of the object.
#  |      This string has to be unique and to be a python and
#  |      javascript-compatible
#  |      variable name.
#  |
#  |  get_root(self)
#  |      Returns the root of the elements tree.
#  |
#  |  save(self, outfile, close_file=True, **kwargs)
#  |      Saves an Element into a file.
#  |
#  |      Parameters
#  |      ----------
#  |      outfile : str or file object
#  |          The file (or filename) where you want to output the html.
#  |      close_file : bool, default True
#  |          Whether the file has to be closed after write.
#  |
#  |  to_dict(self, depth=-1, ordered=True, **kwargs)
#  |      Returns a dict representation of the object.
#  |
#  |  to_json(self, depth=-1, **kwargs)
#  |      Returns a JSON representation of the object.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from branca.element.Element:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
