# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '128_Creating an HTML map with python.ipynb',
#  '130-131_ Adding pointers to map..ipynb',
#  'Map.html',
#  'Map1.html',
#  'Untitled.ipynb',
#  'Volcanoes.txt',
#  'Webmap_datasources',
#  'Webmap_datasources.zip',
#  'world.json']

# %%
import folium
import pandas

data = pandas.read_csv("Volcanoes.txt")
data
# Out:
#     VOLCANX020    NUMBER            NAME       LOCATION  \
# 0        509.0  1201-01=           Baker  US-Washington
# 1        511.0  1201-02-    Glacier Peak  US-Washington
# 2        513.0  1201-03-         Rainier  US-Washington
# 3        515.0  1201-05-      St. Helens  US-Washington
# 4        516.0  1201-04-           Adams  US-Washington
# ..         ...       ...             ...            ...
# 57       580.0  1210-03-  Valles Caldera  US-New Mexico
# 58       581.0  1209-02-   Sunset Crater     US-Arizona
# 59       584.0  1203-20-           Amboy  US-California
# 60       586.0  1210-02-    Zuni-Bandera  US-New Mexico
# 61       588.0  1210-01-       Carrizozo  US-New Mexico
#
#                    STATUS    ELEV             TYPE TIMEFRAME        LAT  \
# 0              Historical  3285.0  Stratovolcanoes        D3  48.776798
# 1        Tephrochronology  3213.0    Stratovolcano        D4  48.111801
# 2        Dendrochronology  4392.0    Stratovolcano        D3  46.869801
# ...

# %%
lat = list(data ['LAT'])
lon = list(data ['LON'])
print (lat)
print (lon)
# Out:
# [48.7767982, 48.1118011, 46.8698006, 46.1997986, 46.2057991, 45.8797989, 45.9297981, 45.3737984, 44.6917992, 44.4197998, 44.3797989, 44.3317986, 44.2848015, 44.1697998, 44.0998001, 43.9788017, 43.7218018, 43.5698013, 43.5119019, 43.240799, 43.4719009, 43.3609009, 42.9299011, 44.4299011, 43.0998993, 43.1498985, 42.9999008, 43.419899, 43.4999008, 43.1799011, 42.6058998, 41.5798988, 42.8799019, 41.419899, 41.1778984, 40.9548988, 40.7798996, 40.6799011, 40.6299019, 40.4919014, 38.9698982, 39.3749008, 39.6500015, 37.9999008, 38.9700012, 37.8799019, 37.6918983, 37.6999016, 37.5798988, 37.0199013, 37.5800018, 37.257, 37.3279991, 36.3578987, 36.0298996, 36.3800011, 34.75, 35.8699989, 35.3699989, 34.5499992, 34.7999992, 33.7801018]
# ...

# %%
#Adding markers from file volcanoes.txt 

map = folium.Map(location = [39.86, -105.00],zoom_start = 5,tiles = "Stamen Terrain")
fg = folium.FeatureGroup(name = "Watashi no map")     

for lt,ln in zip(lat,lon):
    fg.add_child(folium.Marker(location = [lt,ln],popup = "Hi i am a marker", icon = folium.Icon(colour = "green")))

map.add_child(fg)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
